# %% [markdown]
# # 🏠 House Price Prediction
# Using California Housing dataset with RandomForest

# %%
from sklearn.datasets import fetch_california_housing
data = fetch_california_housing(as_frame=True)
df = data.frame
df.head()
